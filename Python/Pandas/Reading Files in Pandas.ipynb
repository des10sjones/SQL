# %% [markdown]
# # Reading Files

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DestinJones\Desktop\Pandas Test\C910992 - CIGAR CHARLIE'S True.CSV")

# %%
df
# Out:
#      Cust No.  Item No.                        Description  \
# 0      910992  100032.0                      CAMEL REGULAR
# 1      910992  100040.0                  CAMEL FILTER KING
# 2      910992  100057.0                    CAMEL BLUE KING
# 3      910992  100065.0                CAMEL BLUE BOX KING
# 4      910992  100107.0                       SALEM BOX KS
# ...       ...       ...                                ...
# 4445   910992  837120.0   SCS - COFF MORNING ROAST 40/2.5Z
# 4446   910992  837138.0  SCS - FROZE UP CHERRY LIMEADE 32Z
# 4447   910992  837146.0      SCS - FROZE UP OCEAN BLUE 32Z
# 4448   910992  837187.0   SCS - LUZIANNE PRESWT TEA 3.33LB
# 4449               NaN                                NaN
#
#                  Description.1   UPC 2 - Box  U/M     Packed Retail Pack  \
# 0                R.J. REYNOLDS  1.230010e+10  CTN  00010 PAK       10/CT
# 1                R.J. REYNOLDS  1.230010e+10  CTN  00010 PAK       10/CT
# ...

# %%
df2 = pd.read_excel(r"S:\Brittanie & Chris\Verizon AT&T\EQUIPMENT - Cipher Ipad - BTC 12-9-2024.xlsx")
df2
# Out:
#     Unnamed: 0 Wireless Number      BTC #         Issued\nDate  \
# 0          1.0      2058940594          5  2024-02-13 00:00:00
# 1          2.0      2058940606         15  2022-12-05 00:00:00
# 2          3.0      2058940648         20  2013-01-01 00:00:00
# 3          4.0      2058940600         25  2012-07-13 00:00:00
# 4          5.0      2058940579         30  2020-04-05 00:00:00
# 5          6.0      2058940593         35  2012-08-03 00:00:00
# 6          7.0      2058940607         40  2024-10-15 00:00:00
# 7          8.0      2058940602         45  2020-08-05 00:00:00
# 8          9.0      2058940610         53  2019-08-30 00:00:00
# 9         10.0      2058940596         65  2020-05-07 00:00:00
# 10        11.0      2058940603         80  2012-09-08 00:00:00
# 11        12.0      2058940642         85  2016-01-29 00:00:00
# 12        13.0      2058940637         50  2023-09-12 00:00:00
# 13        14.0      2057043235         63  2023-05-11 00:00:00
# ...

# %%
pd.set_option('display.max.columns', 61)
pd.set_option('display.max.columns', 19)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        56 non-null     float64
#  1   Wireless Number   52 non-null     object
#  2   BTC #             56 non-null     object
#  3   Issued
# Date       37 non-null     object
#  4   Order Machine     51 non-null     object
#  5   User Name         57 non-null     object
#  6   Account Number    49 non-null     object
#  7   New Device ID     48 non-null     object
#  8   Ipad
#  Passcode    37 non-null     object
#  9   Itunes:           50 non-null     object
#  10  Pword:            42 non-null     object
#  11  Unnamed: 11       39 non-null     object
#  12  Tableau Password  5 non-null      object
#  13  E-mail Password   14 non-null     object
#  14  Printer           31 non-null     object
#  15  Unnamed: 15       5 non-null      object
# ...

# %%
df2.shape
# Out:
# (61, 19)

# %%
df2.head()
# Out:
#    Unnamed: 0 Wireless Number BTC #         Issued\nDate Order Machine  \
# 0         1.0      2058940594     5  2024-02-13 00:00:00     DB1000214
# 1         2.0      2058940606    15  2022-12-05 00:00:00     DB1000622
# 2         3.0      2058940648    20  2013-01-01 00:00:00     DB2500377
# 3         4.0      2058940600    25  2012-07-13 00:00:00     DBC000038
# 4         5.0      2058940579    30  2020-04-05 00:00:00     DB9000121
#
#        User Name   Account Number    New Device ID Ipad\n Passcode  \
# 0   Jay Chambers  342562672-00001  357652531093661            1927
# 1  Shaw, Patrick  342562672-00001  350698369666828          192715
# 2   CICIO, FRANK  342562672-00001  351036275258449          192720
# 3   JONES, JACOB  342562672-00001  351036274751675          192725
# 4  GRAVLEE,MACON  342562672-00001  351613968288550            1927
#
#                       Itunes:   Pword:  Unnamed: 11 Tableau Password  \
# ...

# %%
df2.loc[35]
# Out:
# Unnamed: 0                       34.0
# Wireless Number            2055182345
# BTC #                           MGMT
# Issued\nDate                      NaN
# Order Machine                    IPAD
# User Name           Frank D'Amico III
# Account Number        342562672-00001
# New Device ID         355939979905874
# Ipad\n Passcode                   NaN
# Itunes:                           NaN
# Pword:                            NaN
# Unnamed: 11                       NaN
# Tableau Password                  NaN
# E-mail Password                   NaN
# Printer                           NaN
# Unnamed: 15                       NaN
# Unnamed: 16                       NaN
# Unnamed: 17                       NaN
# Unnamed: 18                       NaN
# Name: 35, dtype: object

# %%
df2.iloc[4]
# Out:
# Unnamed: 0                               5.0
# Wireless Number                   2058940579
# BTC #                                     30
# Issued\nDate             2020-04-05 00:00:00
# Order Machine                      DB9000121
# User Name                      GRAVLEE,MACON
# Account Number               342562672-00001
# New Device ID                351613968288550
# Ipad\n Passcode                         1927
# Itunes:             mgravlee@btcwholesal.com
# Pword:                              BTCw1927
# Unnamed: 11                             mg30
# Tableau Password
# E-mail Password                BTC100Gravlee
# Printer                       XXZVN243400653
# Unnamed: 15                              NaN
# Unnamed: 16                              NaN
# Unnamed: 17                              NaN
# Unnamed: 18                              NaN
# Name: 4, dtype: object
